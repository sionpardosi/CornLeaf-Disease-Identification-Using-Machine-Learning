# %%
import os
import time
import shutil
import pathlib
import itertools
from PIL import Image

import cv2
import numpy as np
import pandas as pd
import seaborn as sns
sns.set_style('darkgrid')
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix, classification_report

import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.models import Sequential
from tensorflow.keras.optimizers import Adam, Adamax
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Activation, Dropout, BatchNormalization
from tensorflow.keras import regularizers

import warnings
warnings.filterwarnings("ignore")

print ('modules loaded')
# Out:
# modules loaded

# %%
data_path = "Dataset/data" 

images = []
labels = []

for subfolder in os.listdir(data_path):
    
    subfolder_path = os.path.join(data_path, subfolder)
    if not os.path.isdir(subfolder_path):
        continue
  
    for image_filename in os.listdir(subfolder_path):
        image_path = os.path.join(subfolder_path, image_filename)
        images.append(image_path)
    
        labels.append(subfolder)
 
data = pd.DataFrame({'image': images, 'label': labels})

# %%
data.head()
# Out:
#                                         image   label
# 0    Dataset/data\Blight\Corn_Blight (1).jpeg  Blight
# 1     Dataset/data\Blight\Corn_Blight (1).jpg  Blight
# 2    Dataset/data\Blight\Corn_Blight (10).jpg  Blight
# 3   Dataset/data\Blight\Corn_Blight (100).jpg  Blight
# 4  Dataset/data\Blight\Corn_Blight (1000).JPG  Blight

# %%
strat = data['label']
train_df, dummy_df = train_test_split(data,  train_size= 0.81, shuffle= True, random_state= 123, stratify= strat)

strat = dummy_df['label']
valid_df, test_df = train_test_split(dummy_df,  train_size= 0.5, shuffle= True, random_state= 123, stratify= strat)

# %%
batch_size = 32
img_size = (224, 224)
channels = 3
img_shape = (img_size[0], img_size[1], channels)

tr_gen = ImageDataGenerator()
ts_gen = ImageDataGenerator()

train_gen = tr_gen.flow_from_dataframe(train_df, x_col='image', y_col='label', target_size=img_size, class_mode='categorical', color_mode='rgb', shuffle=True, batch_size=batch_size)

valid_gen = ts_gen.flow_from_dataframe(valid_df, x_col='image', y_col='label', target_size=img_size, class_mode='categorical', color_mode='rgb', shuffle=True, batch_size=batch_size)


test_gen = ts_gen.flow_from_dataframe(test_df, x_col='image', y_col='label', target_size=img_size, class_mode='categorical', color_mode='rgb', shuffle=False, batch_size=batch_size)
# Out:
# Found 3392 validated image filenames belonging to 4 classes.
# Found 398 validated image filenames belonging to 4 classes.
# Found 398 validated image filenames belonging to 4 classes.

# %%
g_dict = train_gen.class_indices      
classes = list(g_dict.keys())       
images, labels = next(train_gen)      

plt.figure(figsize= (12, 12))

for i in range(16):
    plt.subplot(4, 4, i + 1)
    image = images[i] / 255       
    plt.imshow(image)
    index = np.argmax(labels[i])  
    class_name = classes[index]   
    plt.title(class_name, color= 'blue', fontsize= 10)
    plt.axis('off')
plt.show()

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

def apply_canny_edge_detection(image):
    if len(image.shape) == 3:  
        gray_image = cv2.cvtColor(image, cv2.COLOR_RGB2GRAY)
    else:
        gray_image = image
    
    gray_image = gray_image.astype(np.uint8)
    
    edges = cv2.Canny(gray_image, 100, 200)
    
    return edges

g_dict = train_gen.class_indices      
classes = list(g_dict.keys())       

images, labels = next(train_gen)      

plt.figure(figsize=(12, 12))

for i in range(16):
    plt.subplot(4, 4, i + 1)
    
    edges = apply_canny_edge_detection(images[i])
    
    edges_rgb = cv2.cvtColor(edges, cv2.COLOR_GRAY2RGB)
    
    plt.imshow(edges_rgb)
    index = np.argmax(labels[i])  
    class_name = classes[index]   
    plt.title(class_name, color='blue', fontsize=10)
    plt.axis('off')

plt.show()

# %%
model = Sequential()

model.add(tf.keras.layers.InputLayer(input_shape=(224, 224, 3)))

model.add(Conv2D(filters=32, kernel_size=(3, 3), padding='same', activation='relu'))
model.add(BatchNormalization())
model.add(MaxPooling2D(pool_size=(2, 2)))

model.add(Conv2D(filters=64, kernel_size=(3, 3), padding='same', activation='relu'))
model.add(BatchNormalization())
model.add(MaxPooling2D(pool_size=(2, 2)))

model.add(Conv2D(filters=128, kernel_size=(3, 3), padding='same', activation='relu'))
model.add(BatchNormalization())
model.add(MaxPooling2D(pool_size=(2, 2)))

model.add(Conv2D(filters=256, kernel_size=(3, 3), padding='same', activation='relu'))
model.add(BatchNormalization())
model.add(MaxPooling2D(pool_size=(2, 2)))

model.add(Flatten())
model.add(Dropout(0.5))
model.add(Dense(512, activation='relu', kernel_regularizer=tf.keras.regularizers.l2(0.0001)))
model.add(Dropout(0.5))
model.add(Dense(128, activation='relu', kernel_regularizer=tf.keras.regularizers.l2(0.0001)))
model.add(Dense(4, activation='softmax'))

model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ conv2d (Conv2D)                      │ (None, 224, 224, 32)        │             896 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization                  │ (None, 224, 224, 32)        │             128 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d (MaxPooling2D)         │ (None, 112, 112, 32)        │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_1 (Conv2D)                    │ (None, 112, 112, 64)        │          18,496 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_1                │ (None, 112, 112, 64)        │             256 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_1 (MaxPooling2D)       │ (None, 56, 56, 64)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_2 (Conv2D)                    │ (None, 56, 56, 128)         │          73,856 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_2                │ (None, 56, 56, 128)         │             512 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_2 (MaxPooling2D)       │ (None, 28, 28, 128)         │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_3 (Conv2D)                    │ (None, 28, 28, 256)         │         295,168 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_3                │ (None, 28, 28, 256)         │           1,024 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_3 (MaxPooling2D)       │ (None, 14, 14, 256)         │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ flatten (Flatten)                    │ (None, 50176)               │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout (Dropout)                    │ (None, 50176)               │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense (Dense)                        │ (None, 512)                 │      25,690,624 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_1 (Dropout)                  │ (None, 512)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_1 (Dense)                      │ (None, 128)                 │          65,664 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_2 (Dense)                      │ (None, 4)                   │             516 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 26,147,140 (99.74 MB)
#  Trainable params: 26,146,180 (99.74 MB)
#  Non-trainable params: 960 (3.75 KB)

# %%
model.save('model1.h5')
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.

# %%
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping


early_stopping = EarlyStopping(
    monitor='val_accuracy',
    patience=10,
    restore_best_weights=True,
    verbose=1
)

checkpoint = ModelCheckpoint(
    filepath='kaggle/working/model1.keras',
    monitor='val_accuracy',
    save_best_only=True,
    mode='max',
    verbose=1
)

model.compile(optimizer=tf.keras.optimizers.Adamax(learning_rate=0.001),
              loss='categorical_crossentropy',
              metrics=['accuracy'])

# %%
train_datagen = ImageDataGenerator(
    rescale=1./255,
    horizontal_flip=True,
    vertical_flip=True,
    rotation_range=30,
    width_shift_range=0.2,
    height_shift_range=0.2,
    shear_range=0.2,
    zoom_range=0.2,
    fill_mode='nearest'
)

valid_datagen = ImageDataGenerator(rescale=1./255)

train_gen = train_datagen.flow_from_directory(
    "Dataset/data",
    target_size=(224, 224),
    batch_size=32,
    class_mode='categorical'
)

valid_gen = valid_datagen.flow_from_directory(
    "Dataset/data",
    target_size=(224, 224),
    batch_size=32,
    class_mode='categorical'
)

history = model.fit(
    train_gen,
    epochs=30,
    validation_data=valid_gen,
    callbacks=[early_stopping, checkpoint]
)
# Out:
# Found 4188 images belonging to 4 classes.
# Found 4188 images belonging to 4 classes.
# Epoch 1/30
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.7231 - loss: 2.9502
# Epoch 1: val_accuracy improved from -inf to 0.13945, saving model to kaggle/working/model1.keras
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 389s 3s/step - accuracy: 0.7234 - loss: 2.9433 - val_accuracy: 0.1394 - val_loss: 3.3664
# Epoch 2/30
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.7934 - loss: 0.9427
# Epoch 2: val_accuracy improved from 0.13945 to 0.52865, saving model to kaggle/working/model1.keras
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 320s 2s/step - accuracy: 0.7935 - loss: 0.9424 - val_accuracy: 0.5287 - val_loss: 3.1742
# Epoch 3/30
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.8148 - loss: 0.7488
# Epoch 3: val_accuracy improved from 0.52865 to 0.53534, saving model to kaggle/working/model1.keras
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 301s 2s/step - accuracy: 0.8148 - loss: 0.7485 - val_accuracy: 0.5353 - val_loss: 3.7059
# Epoch 4/30
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.8288 - loss: 0.6686
# Epoch 4: val_accuracy improved from 0.53534 to 0.83286, saving model to kaggle/working/model1.keras
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 292s 2s/step - accuracy: 0.8289 - loss: 0.6684 - val_accuracy: 0.8329 - val_loss: 0.6021
# Epoch 5/30
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.8326 - loss: 0.6309
# Epoch 5: val_accuracy improved from 0.83286 to 0.88491, saving model to kaggle/working/model1.keras
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 290s 2s/step - accuracy: 0.8327 - loss: 0.6308 - val_accuracy: 0.8849 - val_loss: 0.4482
# Epoch 6/30
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.8538 - loss: 0.5803
# Epoch 6: val_accuracy did not improve from 0.88491
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 289s 2s/step - accuracy: 0.8538 - loss: 0.5802 - val_accuracy: 0.8200 - val_loss: 0.5656
# Epoch 7/30
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.8564 - loss: 0.5456
# Epoch 7: val_accuracy did not improve from 0.88491
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 294s 2s/step - accuracy: 0.8564 - loss: 0.5458 - val_accuracy: 0.7989 - val_loss: 0.6743
# Epoch 8/30
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.8767 - loss: 0.5143
# Epoch 8: val_accuracy improved from 0.88491 to 0.89088, saving model to kaggle/working/model1.keras
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 295s 2s/step - accuracy: 0.8767 - loss: 0.5144 - val_accuracy: 0.8909 - val_loss: 0.4485
# Epoch 9/30
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.8886 - loss: 0.4981
# Epoch 9: val_accuracy did not improve from 0.89088
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 293s 2s/step - accuracy: 0.8885 - loss: 0.4982 - val_accuracy: 0.8142 - val_loss: 0.5706
# Epoch 10/30
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.8761 - loss: 0.4950
# Epoch 10: val_accuracy improved from 0.89088 to 0.89661, saving model to kaggle/working/model1.keras
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 299s 2s/step - accuracy: 0.8761 - loss: 0.4951 - val_accuracy: 0.8966 - val_loss: 0.4194
# Epoch 11/30
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.8805 - loss: 0.4701
# Epoch 11: val_accuracy did not improve from 0.89661
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 297s 2s/step - accuracy: 0.8805 - loss: 0.4701 - val_accuracy: 0.8658 - val_loss: 0.4825
# Epoch 12/30
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.8870 - loss: 0.4667
# Epoch 12: val_accuracy did not improve from 0.89661
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 292s 2s/step - accuracy: 0.8870 - loss: 0.4667 - val_accuracy: 0.8245 - val_loss: 0.6187
# Epoch 13/30
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.8808 - loss: 0.4789
# Epoch 13: val_accuracy did not improve from 0.89661
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 292s 2s/step - accuracy: 0.8808 - loss: 0.4787 - val_accuracy: 0.8899 - val_loss: 0.4351
# Epoch 14/30
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.8900 - loss: 0.4651
# Epoch 14: val_accuracy improved from 0.89661 to 0.92479, saving model to kaggle/working/model1.keras
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 298s 2s/step - accuracy: 0.8900 - loss: 0.4650 - val_accuracy: 0.9248 - val_loss: 0.3693
# Epoch 15/30
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9001 - loss: 0.4247
# Epoch 15: val_accuracy did not improve from 0.92479
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 356s 3s/step - accuracy: 0.9001 - loss: 0.4248 - val_accuracy: 0.9081 - val_loss: 0.3800
# Epoch 16/30
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9037 - loss: 0.4454
# Epoch 16: val_accuracy improved from 0.92479 to 0.93075, saving model to kaggle/working/model1.keras
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 347s 3s/step - accuracy: 0.9037 - loss: 0.4453 - val_accuracy: 0.9308 - val_loss: 0.3458
# Epoch 17/30
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 0s 38s/step - accuracy: 0.9053 - loss: 0.4462
# Epoch 17: val_accuracy did not improve from 0.93075
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 4951s 38s/step - accuracy: 0.9053 - loss: 0.4461 - val_accuracy: 0.9093 - val_loss: 0.4072
# Epoch 18/30
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.8911 - loss: 0.4514
# Epoch 18: val_accuracy did not improve from 0.93075
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 296s 2s/step - accuracy: 0.8912 - loss: 0.4512 - val_accuracy: 0.9126 - val_loss: 0.3754
# Epoch 19/30
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9076 - loss: 0.4032
# Epoch 19: val_accuracy did not improve from 0.93075
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 287s 2s/step - accuracy: 0.9075 - loss: 0.4034 - val_accuracy: 0.9160 - val_loss: 0.3741
# Epoch 20/30
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9143 - loss: 0.3950
# Epoch 20: val_accuracy improved from 0.93075 to 0.93887, saving model to kaggle/working/model1.keras
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 311s 2s/step - accuracy: 0.9143 - loss: 0.3952 - val_accuracy: 0.9389 - val_loss: 0.3199
# Epoch 21/30
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9206 - loss: 0.3795
# Epoch 21: val_accuracy did not improve from 0.93887
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 324s 2s/step - accuracy: 0.9205 - loss: 0.3796 - val_accuracy: 0.8964 - val_loss: 0.4202
# Epoch 22/30
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9087 - loss: 0.4112
# Epoch 22: val_accuracy did not improve from 0.93887
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 321s 2s/step - accuracy: 0.9088 - loss: 0.4110 - val_accuracy: 0.8742 - val_loss: 0.5569
# Epoch 23/30
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9313 - loss: 0.3641
# Epoch 23: val_accuracy did not improve from 0.93887
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 341s 3s/step - accuracy: 0.9313 - loss: 0.3643 - val_accuracy: 0.9331 - val_loss: 0.3268
# Epoch 24/30
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9242 - loss: 0.3729
# Epoch 24: val_accuracy did not improve from 0.93887
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 319s 2s/step - accuracy: 0.9241 - loss: 0.3729 - val_accuracy: 0.9097 - val_loss: 0.4019
# Epoch 25/30
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9218 - loss: 0.3889
# Epoch 25: val_accuracy did not improve from 0.93887
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 302s 2s/step - accuracy: 0.9218 - loss: 0.3889 - val_accuracy: 0.9083 - val_loss: 0.4138
# Epoch 26/30
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9177 - loss: 0.3795
# Epoch 26: val_accuracy improved from 0.93887 to 0.94198, saving model to kaggle/working/model1.keras
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 316s 2s/step - accuracy: 0.9177 - loss: 0.3795 - val_accuracy: 0.9420 - val_loss: 0.3130
# Epoch 27/30
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9145 - loss: 0.3684
# Epoch 27: val_accuracy did not improve from 0.94198
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 315s 2s/step - accuracy: 0.9146 - loss: 0.3685 - val_accuracy: 0.9112 - val_loss: 0.4173
# Epoch 28/30
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9211 - loss: 0.3974
# Epoch 28: val_accuracy did not improve from 0.94198
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 337s 3s/step - accuracy: 0.9211 - loss: 0.3972 - val_accuracy: 0.9260 - val_loss: 0.3795
# Epoch 29/30
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9235 - loss: 0.3978
# Epoch 29: val_accuracy did not improve from 0.94198
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 333s 3s/step - accuracy: 0.9236 - loss: 0.3975 - val_accuracy: 0.9059 - val_loss: 0.4513
# Epoch 30/30
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9364 - loss: 0.3356
# Epoch 30: val_accuracy did not improve from 0.94198
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 349s 3s/step - accuracy: 0.9364 - loss: 0.3357 - val_accuracy: 0.9181 - val_loss: 0.3792
# Restoring model weights from the end of the best epoch: 26.

# %%
tr_acc = history.history['accuracy']
tr_loss = history.history['loss']
val_acc = history.history['val_accuracy']
val_loss = history.history['val_loss']
index_loss = np.argmin(val_loss)
val_lowest = val_loss[index_loss]
index_acc = np.argmax(val_acc)
acc_highest = val_acc[index_acc]
Epochs = [i+1 for i in range(len(tr_acc))]
loss_label = f'best epoch= {str(index_loss + 1)}'
acc_label = f'best epoch= {str(index_acc + 1)}'

plt.figure(figsize= (20, 8))
plt.style.use('fivethirtyeight')

plt.subplot(1, 2, 1)
plt.plot(Epochs, tr_loss, 'r', label= 'Training loss')
plt.plot(Epochs, val_loss, 'g', label= 'Validation loss')
plt.scatter(index_loss + 1, val_lowest, s= 150, c= 'blue', label= loss_label)
plt.title('Training and Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()

plt.subplot(1, 2, 2)
plt.plot(Epochs, tr_acc, 'r', label= 'Training Accuracy')
plt.plot(Epochs, val_acc, 'g', label= 'Validation Accuracy')
plt.scatter(index_acc + 1 , acc_highest, s= 150, c= 'blue', label= acc_label)
plt.title('Training and Validation Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()

plt.tight_layout
plt.show()

# %%
loss, accuracy = model.evaluate(valid_gen)
print("Accuracy score:", accuracy)
# Out:
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 52s 392ms/step - accuracy: 0.9429 - loss: 0.3004
# Accuracy score: 0.9419770836830139

# %%
import numpy as np
from tensorflow.keras.preprocessing import image
import tensorflow as tf

def predict_image(model, img_path):
    # Load image dan ubah ukuran agar sesuai dengan input model
    img = image.load_img(img_path, target_size=(224, 224))

    # Mengubah gambar menjadi array
    img_array = image.img_to_array(img)

    # Menambahkan dimensi batch (batch_size = 1)
    img_array = np.expand_dims(img_array, axis=0)

    # Normalisasi gambar (sesuai dengan preprocessing yang digunakan pada training)
    img_array = img_array / 255.0  # Normalisasi jika menggunakan ImageDataGenerator dengan rescale=1./255

    # Melakukan prediksi dengan model
    prediction = model.predict(img_array)

    # Menampilkan probabilitas untuk setiap kelas
    print(f"Probabilitas untuk setiap kelas: {prediction[0]}")

    return prediction

# Contoh pemakaian:
img_path = 'Dataset/data/Healthy/Corn_Health (1).jpg'  # Ganti dengan path gambar yang ingin diprediksi
prediction = predict_image(model, img_path)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 909ms/step
# Probabilitas untuk setiap kelas: [2.0327318e-06 9.9841584e-09 2.2337211e-07 9.9999774e-01]

# %%
import numpy as np
from tensorflow.keras.preprocessing import image

def predict_image(model, img_path):
    # Load image dan ubah ukuran agar sesuai dengan input model
    img = image.load_img(img_path, target_size=(224, 224))

    # Mengubah gambar menjadi array
    img_array = image.img_to_array(img)

    # Menambahkan dimensi batch (batch_size = 1)
    img_array = np.expand_dims(img_array, axis=0)

    # Normalisasi gambar (sesuai dengan preprocessing yang digunakan pada training)
    img_array = img_array / 255.0  # Normalisasi jika menggunakan ImageDataGenerator dengan rescale=1./255

    # Melakukan prediksi dengan model
    prediction = model.predict(img_array)

    # Daftar label yang sesuai dengan indeks kelas
    class_labels = {0: 'hawar', 1: 'karat', 2: 'bercak', 3: 'sehat'}

    # Menampilkan probabilitas untuk setiap kelas dalam format persen
    print("Probabilitas untuk setiap kelas (dalam persen):")
    probabilities = prediction[0] * 100  # Mengubah ke persentase
    for i, prob in enumerate(probabilities):
        print(f"{class_labels[i]}: {prob:.2f}%")

    # Menentukan index kelas dengan probabilitas tertinggi
    predicted_index = np.argmax(prediction)

    # Menampilkan index dan probabilitas kelas yang diprediksi
    print(f'\nKelas yang diprediksi: {class_labels[predicted_index]} dengan probabilitas {probabilities[predicted_index]:.2f}%')

    return predicted_index, prediction

# Contoh pemakaian:
img_path = 'Dataset/data/Healthy/CamScanner 04-11-2024 20.46_3.jpg'  # Ganti dengan path gambar yang ingin diprediksi
predicted_index, prediction = predict_image(model, img_path)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# Probabilitas untuk setiap kelas (dalam persen):
# hawar: 0.06%
# karat: 0.00%
# bercak: 0.00%
# sehat: 99.94%
#
# Kelas yang diprediksi: sehat dengan probabilitas 99.94%
